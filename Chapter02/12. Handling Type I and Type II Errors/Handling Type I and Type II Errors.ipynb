# %% [markdown]
# 1종 오류와 2종 오류 처리
# - 어떤 유형의 오류가 다른 유형의 오류보다 중요할 수 있음
# - PDF 파일과 같이 파일이 매우 일반적이지만 거의 드문 악성코드인 경우 원하는 오탐율은 0.01%와 같이 매우 낮음
# - 한계점(threshold)을 사용하여 원하는 오탐율의 한계를 넘지 않도록 하는 방법 사용
# - 데이터셋을 가져와 분류기 훈련하고 나서 오탐율 제약 조건 충족시키고자 한계점 조정

# %%
# 데이터셋을 가져오고 원하는 오탐율이 1% 이하라는 것 지정
import numpy as np
from scipy import sparse
import scipy

X_train = scipy.sparse.load_npz("../Resources/training_data.npz")
y_train = np.load("../Resources/training_labels.npy")
X_test = scipy.sparse.load_npz("../Resources/test_data.npz")
y_test = np.load("../Resources/test_labels.npy")
desired_FPR = 0.01

# %%
# 오탐율(False Positive Rate)과 정탐율(True Positive Rate) 계산하는 함수 만듦
from sklearn.metrics import confusion_matrix


def FPR(y_true, y_pred):
    """Calculate the False Positive Rate."""
    CM = confusion_matrix(y_true, y_pred)
    TN = CM[0][0]
    FP = CM[0][1]
    return FP / (FP + TN)


def TPR(y_true, y_pred):
    """Calculate the True Positive Rate."""
    CM = confusion_matrix(y_true, y_pred)
    TP = CM[1][1]
    FN = CM[1][0]
    return TP / (TP + FN)

# %%
# 한계점을 사용하여 확률 벡터를 bool 벡터로 변환하는 함수 만듦
def perform_thresholding(vector, threshold):
    """Threshold a vector."""
    return [0 if x >= threshold else 1 for x in vector]

# %%
# XGBoost 모델을 훈련하고 훈련 데이터에 대한 예측 확률 계산
from xgboost import XGBClassifier

clf = XGBClassifier()
clf.fit(X_train, y_train)
clf_pred_prob = clf.predict_proba(X_train)

# %%
# 예측 확률 벡터를 확인
print("Probabilities look like so:")
print(clf_pred_prob[0:5])
print()
# Out:
# Probabilities look like so:
# [[9.9711573e-01 2.8842732e-03]
#  [9.9930882e-01 6.9116493e-04]
#  [9.9943042e-01 5.6955573e-04]
#  [9.8729378e-01 1.2706242e-02]
#  [9.0440232e-01 9.5597707e-02]]

# %%
# 1000개의 다른 한계점 값에 대해 반복하면서 각 한계점에 대한 오탐율을 계산하고, FPR<=DesiredFDP을 만족할 때 한계점 값을 계산
M = 1000
print("Fitting threshold:")
for t in reversed(range(M)):
    scaled_threshold = float(t) / M
    thresholded_prediction = perform_thresholding(clf_pred_prob[:, 0], scaled_threshold)
    FPR_=FPR(y_train, thresholded_prediction)
    TPR_=TPR(y_train, thresholded_prediction)
    print(f"{t:03}번째 시도 한계점: {scaled_threshold:.3f}, 오탐율:{FPR_:.4f}, 정탐율: {TPR_:.4f}")
    if FPR_ <= desired_FPR:
        print()
        print("Selected threshold: ")
        print(scaled_threshold)
        break
# Out:
# Fitting threshold:
# 999번째 시도 한계점: 0.999, 오탐율:0.4682, 정탐율: 1.0000
# 998번째 시도 한계점: 0.998, 오탐율:0.3364, 정탐율: 1.0000
# 997번째 시도 한계점: 0.997, 오탐율:0.2182, 정탐율: 1.0000
# 996번째 시도 한계점: 0.996, 오탐율:0.1864, 정탐율: 1.0000
# 995번째 시도 한계점: 0.995, 오탐율:0.1682, 정탐율: 1.0000
# 994번째 시도 한계점: 0.994, 오탐율:0.1500, 정탐율: 1.0000
# 993번째 시도 한계점: 0.993, 오탐율:0.1409, 정탐율: 1.0000
# 992번째 시도 한계점: 0.992, 오탐율:0.1273, 정탐율: 1.0000
# 991번째 시도 한계점: 0.991, 오탐율:0.1182, 정탐율: 1.0000
# 990번째 시도 한계점: 0.990, 오탐율:0.1136, 정탐율: 1.0000
# 989번째 시도 한계점: 0.989, 오탐율:0.1136, 정탐율: 1.0000
# 988번째 시도 한계점: 0.988, 오탐율:0.1136, 정탐율: 1.0000
# 987번째 시도 한계점: 0.987, 오탐율:0.1091, 정탐율: 1.0000
# 986번째 시도 한계점: 0.986, 오탐율:0.1091, 정탐율: 1.0000
# 985번째 시도 한계점: 0.985, 오탐율:0.1091, 정탐율: 1.0000
# 984번째 시도 한계점: 0.984, 오탐율:0.1000, 정탐율: 1.0000
# 983번째 시도 한계점: 0.983, 오탐율:0.1000, 정탐율: 1.0000
# 982번째 시도 한계점: 0.982, 오탐율:0.1000, 정탐율: 1.0000
# 981번째 시도 한계점: 0.981, 오탐율:0.1000, 정탐율: 1.0000
# 980번째 시도 한계점: 0.980, 오탐율:0.1000, 정탐율: 1.0000
# 979번째 시도 한계점: 0.979, 오탐율:0.1000, 정탐율: 1.0000
# 978번째 시도 한계점: 0.978, 오탐율:0.1000, 정탐율: 1.0000
# 977번째 시도 한계점: 0.977, 오탐율:0.1000, 정탐율: 1.0000
# 976번째 시도 한계점: 0.976, 오탐율:0.1000, 정탐율: 1.0000
# 975번째 시도 한계점: 0.975, 오탐율:0.0955, 정탐율: 1.0000
# 974번째 시도 한계점: 0.974, 오탐율:0.0955, 정탐율: 1.0000
# 973번째 시도 한계점: 0.973, 오탐율:0.0909, 정탐율: 1.0000
# 972번째 시도 한계점: 0.972, 오탐율:0.0909, 정탐율: 1.0000
# 971번째 시도 한계점: 0.971, 오탐율:0.0773, 정탐율: 1.0000
# 970번째 시도 한계점: 0.970, 오탐율:0.0773, 정탐율: 1.0000
# 969번째 시도 한계점: 0.969, 오탐율:0.0773, 정탐율: 1.0000
# 968번째 시도 한계점: 0.968, 오탐율:0.0773, 정탐율: 1.0000
# 967번째 시도 한계점: 0.967, 오탐율:0.0773, 정탐율: 1.0000
# 966번째 시도 한계점: 0.966, 오탐율:0.0773, 정탐율: 1.0000
# 965번째 시도 한계점: 0.965, 오탐율:0.0773, 정탐율: 1.0000
# 964번째 시도 한계점: 0.964, 오탐율:0.0773, 정탐율: 1.0000
# 963번째 시도 한계점: 0.963, 오탐율:0.0773, 정탐율: 1.0000
# 962번째 시도 한계점: 0.962, 오탐율:0.0773, 정탐율: 1.0000
# 961번째 시도 한계점: 0.961, 오탐율:0.0773, 정탐율: 1.0000
# 960번째 시도 한계점: 0.960, 오탐율:0.0773, 정탐율: 1.0000
# 959번째 시도 한계점: 0.959, 오탐율:0.0682, 정탐율: 1.0000
# 958번째 시도 한계점: 0.958, 오탐율:0.0682, 정탐율: 1.0000
# 957번째 시도 한계점: 0.957, 오탐율:0.0682, 정탐율: 1.0000
# 956번째 시도 한계점: 0.956, 오탐율:0.0682, 정탐율: 1.0000
# 955번째 시도 한계점: 0.955, 오탐율:0.0682, 정탐율: 1.0000
# 954번째 시도 한계점: 0.954, 오탐율:0.0682, 정탐율: 1.0000
# 953번째 시도 한계점: 0.953, 오탐율:0.0682, 정탐율: 1.0000
# 952번째 시도 한계점: 0.952, 오탐율:0.0682, 정탐율: 1.0000
# 951번째 시도 한계점: 0.951, 오탐율:0.0636, 정탐율: 1.0000
# 950번째 시도 한계점: 0.950, 오탐율:0.0636, 정탐율: 1.0000
# 949번째 시도 한계점: 0.949, 오탐율:0.0636, 정탐율: 1.0000
# 948번째 시도 한계점: 0.948, 오탐율:0.0636, 정탐율: 1.0000
# 947번째 시도 한계점: 0.947, 오탐율:0.0636, 정탐율: 1.0000
# 946번째 시도 한계점: 0.946, 오탐율:0.0636, 정탐율: 1.0000
# 945번째 시도 한계점: 0.945, 오탐율:0.0636, 정탐율: 1.0000
# 944번째 시도 한계점: 0.944, 오탐율:0.0636, 정탐율: 1.0000
# 943번째 시도 한계점: 0.943, 오탐율:0.0636, 정탐율: 1.0000
# 942번째 시도 한계점: 0.942, 오탐율:0.0636, 정탐율: 1.0000
# 941번째 시도 한계점: 0.941, 오탐율:0.0636, 정탐율: 1.0000
# 940번째 시도 한계점: 0.940, 오탐율:0.0636, 정탐율: 1.0000
# 939번째 시도 한계점: 0.939, 오탐율:0.0636, 정탐율: 1.0000
# 938번째 시도 한계점: 0.938, 오탐율:0.0636, 정탐율: 1.0000
# 937번째 시도 한계점: 0.937, 오탐율:0.0636, 정탐율: 1.0000
# 936번째 시도 한계점: 0.936, 오탐율:0.0636, 정탐율: 1.0000
# 935번째 시도 한계점: 0.935, 오탐율:0.0636, 정탐율: 1.0000
# 934번째 시도 한계점: 0.934, 오탐율:0.0636, 정탐율: 1.0000
# 933번째 시도 한계점: 0.933, 오탐율:0.0636, 정탐율: 1.0000
# 932번째 시도 한계점: 0.932, 오탐율:0.0636, 정탐율: 1.0000
# 931번째 시도 한계점: 0.931, 오탐율:0.0636, 정탐율: 1.0000
# 930번째 시도 한계점: 0.930, 오탐율:0.0636, 정탐율: 1.0000
# 929번째 시도 한계점: 0.929, 오탐율:0.0636, 정탐율: 1.0000
# 928번째 시도 한계점: 0.928, 오탐율:0.0636, 정탐율: 1.0000
# 927번째 시도 한계점: 0.927, 오탐율:0.0636, 정탐율: 1.0000
# 926번째 시도 한계점: 0.926, 오탐율:0.0636, 정탐율: 1.0000
# 925번째 시도 한계점: 0.925, 오탐율:0.0636, 정탐율: 1.0000
# 924번째 시도 한계점: 0.924, 오탐율:0.0636, 정탐율: 1.0000
# 923번째 시도 한계점: 0.923, 오탐율:0.0636, 정탐율: 1.0000
# 922번째 시도 한계점: 0.922, 오탐율:0.0636, 정탐율: 1.0000
# 921번째 시도 한계점: 0.921, 오탐율:0.0636, 정탐율: 1.0000
# 920번째 시도 한계점: 0.920, 오탐율:0.0636, 정탐율: 1.0000
# 919번째 시도 한계점: 0.919, 오탐율:0.0636, 정탐율: 1.0000
# 918번째 시도 한계점: 0.918, 오탐율:0.0636, 정탐율: 1.0000
# 917번째 시도 한계점: 0.917, 오탐율:0.0636, 정탐율: 1.0000
# 916번째 시도 한계점: 0.916, 오탐율:0.0636, 정탐율: 1.0000
# 915번째 시도 한계점: 0.915, 오탐율:0.0636, 정탐율: 1.0000
# 914번째 시도 한계점: 0.914, 오탐율:0.0636, 정탐율: 1.0000
# 913번째 시도 한계점: 0.913, 오탐율:0.0591, 정탐율: 1.0000
# 912번째 시도 한계점: 0.912, 오탐율:0.0591, 정탐율: 1.0000
# 911번째 시도 한계점: 0.911, 오탐율:0.0591, 정탐율: 1.0000
# 910번째 시도 한계점: 0.910, 오탐율:0.0591, 정탐율: 1.0000
# 909번째 시도 한계점: 0.909, 오탐율:0.0591, 정탐율: 1.0000
# 908번째 시도 한계점: 0.908, 오탐율:0.0591, 정탐율: 1.0000
# 907번째 시도 한계점: 0.907, 오탐율:0.0591, 정탐율: 1.0000
# 906번째 시도 한계점: 0.906, 오탐율:0.0591, 정탐율: 1.0000
# 905번째 시도 한계점: 0.905, 오탐율:0.0591, 정탐율: 1.0000
# 904번째 시도 한계점: 0.904, 오탐율:0.0545, 정탐율: 1.0000
# 903번째 시도 한계점: 0.903, 오탐율:0.0545, 정탐율: 1.0000
# 902번째 시도 한계점: 0.902, 오탐율:0.0545, 정탐율: 1.0000
# 901번째 시도 한계점: 0.901, 오탐율:0.0545, 정탐율: 1.0000
# 900번째 시도 한계점: 0.900, 오탐율:0.0545, 정탐율: 1.0000
# 899번째 시도 한계점: 0.899, 오탐율:0.0545, 정탐율: 1.0000
# 898번째 시도 한계점: 0.898, 오탐율:0.0545, 정탐율: 1.0000
# 897번째 시도 한계점: 0.897, 오탐율:0.0545, 정탐율: 1.0000
# 896번째 시도 한계점: 0.896, 오탐율:0.0545, 정탐율: 1.0000
# 895번째 시도 한계점: 0.895, 오탐율:0.0545, 정탐율: 1.0000
# 894번째 시도 한계점: 0.894, 오탐율:0.0545, 정탐율: 1.0000
# 893번째 시도 한계점: 0.893, 오탐율:0.0545, 정탐율: 1.0000
# 892번째 시도 한계점: 0.892, 오탐율:0.0545, 정탐율: 1.0000
# 891번째 시도 한계점: 0.891, 오탐율:0.0545, 정탐율: 1.0000
# 890번째 시도 한계점: 0.890, 오탐율:0.0545, 정탐율: 1.0000
# 889번째 시도 한계점: 0.889, 오탐율:0.0545, 정탐율: 1.0000
# 888번째 시도 한계점: 0.888, 오탐율:0.0545, 정탐율: 1.0000
# 887번째 시도 한계점: 0.887, 오탐율:0.0545, 정탐율: 1.0000
# 886번째 시도 한계점: 0.886, 오탐율:0.0545, 정탐율: 1.0000
# 885번째 시도 한계점: 0.885, 오탐율:0.0545, 정탐율: 1.0000
# 884번째 시도 한계점: 0.884, 오탐율:0.0545, 정탐율: 1.0000
# 883번째 시도 한계점: 0.883, 오탐율:0.0545, 정탐율: 1.0000
# 882번째 시도 한계점: 0.882, 오탐율:0.0545, 정탐율: 1.0000
# 881번째 시도 한계점: 0.881, 오탐율:0.0545, 정탐율: 1.0000
# 880번째 시도 한계점: 0.880, 오탐율:0.0545, 정탐율: 1.0000
# 879번째 시도 한계점: 0.879, 오탐율:0.0545, 정탐율: 1.0000
# 878번째 시도 한계점: 0.878, 오탐율:0.0545, 정탐율: 1.0000
# 877번째 시도 한계점: 0.877, 오탐율:0.0545, 정탐율: 1.0000
# 876번째 시도 한계점: 0.876, 오탐율:0.0545, 정탐율: 1.0000
# 875번째 시도 한계점: 0.875, 오탐율:0.0545, 정탐율: 1.0000
# 874번째 시도 한계점: 0.874, 오탐율:0.0545, 정탐율: 1.0000
# 873번째 시도 한계점: 0.873, 오탐율:0.0545, 정탐율: 1.0000
# 872번째 시도 한계점: 0.872, 오탐율:0.0545, 정탐율: 1.0000
# 871번째 시도 한계점: 0.871, 오탐율:0.0545, 정탐율: 1.0000
# 870번째 시도 한계점: 0.870, 오탐율:0.0545, 정탐율: 1.0000
# 869번째 시도 한계점: 0.869, 오탐율:0.0545, 정탐율: 1.0000
# 868번째 시도 한계점: 0.868, 오탐율:0.0545, 정탐율: 1.0000
# 867번째 시도 한계점: 0.867, 오탐율:0.0545, 정탐율: 1.0000
# 866번째 시도 한계점: 0.866, 오탐율:0.0545, 정탐율: 1.0000
# 865번째 시도 한계점: 0.865, 오탐율:0.0545, 정탐율: 1.0000
# 864번째 시도 한계점: 0.864, 오탐율:0.0545, 정탐율: 1.0000
# 863번째 시도 한계점: 0.863, 오탐율:0.0545, 정탐율: 1.0000
# 862번째 시도 한계점: 0.862, 오탐율:0.0545, 정탐율: 1.0000
# 861번째 시도 한계점: 0.861, 오탐율:0.0545, 정탐율: 1.0000
# 860번째 시도 한계점: 0.860, 오탐율:0.0545, 정탐율: 1.0000
# 859번째 시도 한계점: 0.859, 오탐율:0.0545, 정탐율: 1.0000
# 858번째 시도 한계점: 0.858, 오탐율:0.0545, 정탐율: 1.0000
# 857번째 시도 한계점: 0.857, 오탐율:0.0545, 정탐율: 1.0000
# 856번째 시도 한계점: 0.856, 오탐율:0.0545, 정탐율: 1.0000
# 855번째 시도 한계점: 0.855, 오탐율:0.0545, 정탐율: 1.0000
# 854번째 시도 한계점: 0.854, 오탐율:0.0545, 정탐율: 1.0000
# 853번째 시도 한계점: 0.853, 오탐율:0.0545, 정탐율: 1.0000
# 852번째 시도 한계점: 0.852, 오탐율:0.0545, 정탐율: 1.0000
# 851번째 시도 한계점: 0.851, 오탐율:0.0545, 정탐율: 1.0000
# 850번째 시도 한계점: 0.850, 오탐율:0.0545, 정탐율: 1.0000
# 849번째 시도 한계점: 0.849, 오탐율:0.0545, 정탐율: 1.0000
# 848번째 시도 한계점: 0.848, 오탐율:0.0545, 정탐율: 1.0000
# 847번째 시도 한계점: 0.847, 오탐율:0.0545, 정탐율: 1.0000
# 846번째 시도 한계점: 0.846, 오탐율:0.0545, 정탐율: 1.0000
# 845번째 시도 한계점: 0.845, 오탐율:0.0545, 정탐율: 1.0000
# 844번째 시도 한계점: 0.844, 오탐율:0.0545, 정탐율: 1.0000
# 843번째 시도 한계점: 0.843, 오탐율:0.0545, 정탐율: 1.0000
# 842번째 시도 한계점: 0.842, 오탐율:0.0545, 정탐율: 1.0000
# 841번째 시도 한계점: 0.841, 오탐율:0.0545, 정탐율: 1.0000
# 840번째 시도 한계점: 0.840, 오탐율:0.0545, 정탐율: 1.0000
# 839번째 시도 한계점: 0.839, 오탐율:0.0545, 정탐율: 1.0000
# 838번째 시도 한계점: 0.838, 오탐율:0.0545, 정탐율: 1.0000
# 837번째 시도 한계점: 0.837, 오탐율:0.0545, 정탐율: 1.0000
# 836번째 시도 한계점: 0.836, 오탐율:0.0545, 정탐율: 1.0000
# 835번째 시도 한계점: 0.835, 오탐율:0.0545, 정탐율: 1.0000
# 834번째 시도 한계점: 0.834, 오탐율:0.0545, 정탐율: 1.0000
# 833번째 시도 한계점: 0.833, 오탐율:0.0545, 정탐율: 1.0000
# 832번째 시도 한계점: 0.832, 오탐율:0.0545, 정탐율: 1.0000
# 831번째 시도 한계점: 0.831, 오탐율:0.0545, 정탐율: 1.0000
# 830번째 시도 한계점: 0.830, 오탐율:0.0545, 정탐율: 1.0000
# 829번째 시도 한계점: 0.829, 오탐율:0.0545, 정탐율: 1.0000
# 828번째 시도 한계점: 0.828, 오탐율:0.0545, 정탐율: 1.0000
# 827번째 시도 한계점: 0.827, 오탐율:0.0545, 정탐율: 1.0000
# 826번째 시도 한계점: 0.826, 오탐율:0.0545, 정탐율: 1.0000
# 825번째 시도 한계점: 0.825, 오탐율:0.0545, 정탐율: 1.0000
# 824번째 시도 한계점: 0.824, 오탐율:0.0545, 정탐율: 1.0000
# 823번째 시도 한계점: 0.823, 오탐율:0.0545, 정탐율: 1.0000
# 822번째 시도 한계점: 0.822, 오탐율:0.0545, 정탐율: 1.0000
# 821번째 시도 한계점: 0.821, 오탐율:0.0545, 정탐율: 1.0000
# 820번째 시도 한계점: 0.820, 오탐율:0.0545, 정탐율: 1.0000
# 819번째 시도 한계점: 0.819, 오탐율:0.0545, 정탐율: 1.0000
# 818번째 시도 한계점: 0.818, 오탐율:0.0545, 정탐율: 1.0000
# 817번째 시도 한계점: 0.817, 오탐율:0.0545, 정탐율: 1.0000
# 816번째 시도 한계점: 0.816, 오탐율:0.0545, 정탐율: 1.0000
# 815번째 시도 한계점: 0.815, 오탐율:0.0545, 정탐율: 1.0000
# 814번째 시도 한계점: 0.814, 오탐율:0.0545, 정탐율: 1.0000
# 813번째 시도 한계점: 0.813, 오탐율:0.0545, 정탐율: 1.0000
# 812번째 시도 한계점: 0.812, 오탐율:0.0545, 정탐율: 1.0000
# 811번째 시도 한계점: 0.811, 오탐율:0.0545, 정탐율: 1.0000
# 810번째 시도 한계점: 0.810, 오탐율:0.0545, 정탐율: 1.0000
# 809번째 시도 한계점: 0.809, 오탐율:0.0545, 정탐율: 1.0000
# 808번째 시도 한계점: 0.808, 오탐율:0.0545, 정탐율: 1.0000
# 807번째 시도 한계점: 0.807, 오탐율:0.0545, 정탐율: 1.0000
# 806번째 시도 한계점: 0.806, 오탐율:0.0545, 정탐율: 1.0000
# 805번째 시도 한계점: 0.805, 오탐율:0.0545, 정탐율: 1.0000
# 804번째 시도 한계점: 0.804, 오탐율:0.0545, 정탐율: 1.0000
# 803번째 시도 한계점: 0.803, 오탐율:0.0545, 정탐율: 1.0000
# 802번째 시도 한계점: 0.802, 오탐율:0.0545, 정탐율: 1.0000
# 801번째 시도 한계점: 0.801, 오탐율:0.0545, 정탐율: 1.0000
# 800번째 시도 한계점: 0.800, 오탐율:0.0545, 정탐율: 1.0000
# 799번째 시도 한계점: 0.799, 오탐율:0.0545, 정탐율: 1.0000
# 798번째 시도 한계점: 0.798, 오탐율:0.0545, 정탐율: 1.0000
# 797번째 시도 한계점: 0.797, 오탐율:0.0545, 정탐율: 1.0000
# 796번째 시도 한계점: 0.796, 오탐율:0.0545, 정탐율: 1.0000
# 795번째 시도 한계점: 0.795, 오탐율:0.0545, 정탐율: 1.0000
# 794번째 시도 한계점: 0.794, 오탐율:0.0545, 정탐율: 1.0000
# 793번째 시도 한계점: 0.793, 오탐율:0.0545, 정탐율: 1.0000
# 792번째 시도 한계점: 0.792, 오탐율:0.0545, 정탐율: 1.0000
# 791번째 시도 한계점: 0.791, 오탐율:0.0545, 정탐율: 1.0000
# 790번째 시도 한계점: 0.790, 오탐율:0.0545, 정탐율: 1.0000
# 789번째 시도 한계점: 0.789, 오탐율:0.0545, 정탐율: 1.0000
# 788번째 시도 한계점: 0.788, 오탐율:0.0545, 정탐율: 1.0000
# 787번째 시도 한계점: 0.787, 오탐율:0.0545, 정탐율: 1.0000
# 786번째 시도 한계점: 0.786, 오탐율:0.0545, 정탐율: 1.0000
# 785번째 시도 한계점: 0.785, 오탐율:0.0545, 정탐율: 1.0000
# 784번째 시도 한계점: 0.784, 오탐율:0.0545, 정탐율: 1.0000
# 783번째 시도 한계점: 0.783, 오탐율:0.0545, 정탐율: 1.0000
# 782번째 시도 한계점: 0.782, 오탐율:0.0545, 정탐율: 1.0000
# 781번째 시도 한계점: 0.781, 오탐율:0.0545, 정탐율: 1.0000
# 780번째 시도 한계점: 0.780, 오탐율:0.0545, 정탐율: 1.0000
# 779번째 시도 한계점: 0.779, 오탐율:0.0545, 정탐율: 1.0000
# 778번째 시도 한계점: 0.778, 오탐율:0.0545, 정탐율: 1.0000
# 777번째 시도 한계점: 0.777, 오탐율:0.0545, 정탐율: 1.0000
# 776번째 시도 한계점: 0.776, 오탐율:0.0545, 정탐율: 1.0000
# 775번째 시도 한계점: 0.775, 오탐율:0.0545, 정탐율: 1.0000
# 774번째 시도 한계점: 0.774, 오탐율:0.0545, 정탐율: 1.0000
# 773번째 시도 한계점: 0.773, 오탐율:0.0545, 정탐율: 1.0000
# 772번째 시도 한계점: 0.772, 오탐율:0.0545, 정탐율: 1.0000
# 771번째 시도 한계점: 0.771, 오탐율:0.0545, 정탐율: 1.0000
# 770번째 시도 한계점: 0.770, 오탐율:0.0545, 정탐율: 1.0000
# 769번째 시도 한계점: 0.769, 오탐율:0.0545, 정탐율: 1.0000
# 768번째 시도 한계점: 0.768, 오탐율:0.0545, 정탐율: 1.0000
# 767번째 시도 한계점: 0.767, 오탐율:0.0545, 정탐율: 1.0000
# 766번째 시도 한계점: 0.766, 오탐율:0.0545, 정탐율: 1.0000
# 765번째 시도 한계점: 0.765, 오탐율:0.0545, 정탐율: 1.0000
# 764번째 시도 한계점: 0.764, 오탐율:0.0545, 정탐율: 1.0000
# 763번째 시도 한계점: 0.763, 오탐율:0.0545, 정탐율: 1.0000
# 762번째 시도 한계점: 0.762, 오탐율:0.0545, 정탐율: 1.0000
# 761번째 시도 한계점: 0.761, 오탐율:0.0545, 정탐율: 1.0000
# 760번째 시도 한계점: 0.760, 오탐율:0.0545, 정탐율: 1.0000
# 759번째 시도 한계점: 0.759, 오탐율:0.0545, 정탐율: 1.0000
# 758번째 시도 한계점: 0.758, 오탐율:0.0545, 정탐율: 1.0000
# 757번째 시도 한계점: 0.757, 오탐율:0.0545, 정탐율: 1.0000
# 756번째 시도 한계점: 0.756, 오탐율:0.0545, 정탐율: 1.0000
# 755번째 시도 한계점: 0.755, 오탐율:0.0545, 정탐율: 1.0000
# 754번째 시도 한계점: 0.754, 오탐율:0.0545, 정탐율: 1.0000
# 753번째 시도 한계점: 0.753, 오탐율:0.0545, 정탐율: 1.0000
# 752번째 시도 한계점: 0.752, 오탐율:0.0545, 정탐율: 1.0000
# 751번째 시도 한계점: 0.751, 오탐율:0.0545, 정탐율: 1.0000
# 750번째 시도 한계점: 0.750, 오탐율:0.0545, 정탐율: 1.0000
# 749번째 시도 한계점: 0.749, 오탐율:0.0545, 정탐율: 1.0000
# 748번째 시도 한계점: 0.748, 오탐율:0.0545, 정탐율: 1.0000
# 747번째 시도 한계점: 0.747, 오탐율:0.0545, 정탐율: 1.0000
# 746번째 시도 한계점: 0.746, 오탐율:0.0545, 정탐율: 1.0000
# 745번째 시도 한계점: 0.745, 오탐율:0.0545, 정탐율: 1.0000
# 744번째 시도 한계점: 0.744, 오탐율:0.0545, 정탐율: 1.0000
# 743번째 시도 한계점: 0.743, 오탐율:0.0545, 정탐율: 1.0000
# 742번째 시도 한계점: 0.742, 오탐율:0.0545, 정탐율: 1.0000
# 741번째 시도 한계점: 0.741, 오탐율:0.0545, 정탐율: 1.0000
# 740번째 시도 한계점: 0.740, 오탐율:0.0545, 정탐율: 1.0000
# 739번째 시도 한계점: 0.739, 오탐율:0.0545, 정탐율: 1.0000
# 738번째 시도 한계점: 0.738, 오탐율:0.0545, 정탐율: 1.0000
# 737번째 시도 한계점: 0.737, 오탐율:0.0545, 정탐율: 1.0000
# 736번째 시도 한계점: 0.736, 오탐율:0.0545, 정탐율: 1.0000
# 735번째 시도 한계점: 0.735, 오탐율:0.0545, 정탐율: 1.0000
# 734번째 시도 한계점: 0.734, 오탐율:0.0545, 정탐율: 1.0000
# 733번째 시도 한계점: 0.733, 오탐율:0.0545, 정탐율: 1.0000
# 732번째 시도 한계점: 0.732, 오탐율:0.0545, 정탐율: 1.0000
# 731번째 시도 한계점: 0.731, 오탐율:0.0545, 정탐율: 1.0000
# 730번째 시도 한계점: 0.730, 오탐율:0.0545, 정탐율: 1.0000
# 729번째 시도 한계점: 0.729, 오탐율:0.0545, 정탐율: 1.0000
# 728번째 시도 한계점: 0.728, 오탐율:0.0545, 정탐율: 1.0000
# 727번째 시도 한계점: 0.727, 오탐율:0.0545, 정탐율: 1.0000
# 726번째 시도 한계점: 0.726, 오탐율:0.0545, 정탐율: 1.0000
# 725번째 시도 한계점: 0.725, 오탐율:0.0545, 정탐율: 1.0000
# 724번째 시도 한계점: 0.724, 오탐율:0.0545, 정탐율: 1.0000
# 723번째 시도 한계점: 0.723, 오탐율:0.0545, 정탐율: 1.0000
# 722번째 시도 한계점: 0.722, 오탐율:0.0545, 정탐율: 1.0000
# 721번째 시도 한계점: 0.721, 오탐율:0.0545, 정탐율: 1.0000
# 720번째 시도 한계점: 0.720, 오탐율:0.0545, 정탐율: 1.0000
# 719번째 시도 한계점: 0.719, 오탐율:0.0545, 정탐율: 1.0000
# 718번째 시도 한계점: 0.718, 오탐율:0.0545, 정탐율: 1.0000
# 717번째 시도 한계점: 0.717, 오탐율:0.0545, 정탐율: 1.0000
# 716번째 시도 한계점: 0.716, 오탐율:0.0545, 정탐율: 1.0000
# 715번째 시도 한계점: 0.715, 오탐율:0.0545, 정탐율: 1.0000
# 714번째 시도 한계점: 0.714, 오탐율:0.0545, 정탐율: 1.0000
# 713번째 시도 한계점: 0.713, 오탐율:0.0545, 정탐율: 1.0000
# 712번째 시도 한계점: 0.712, 오탐율:0.0545, 정탐율: 1.0000
# 711번째 시도 한계점: 0.711, 오탐율:0.0545, 정탐율: 1.0000
# 710번째 시도 한계점: 0.710, 오탐율:0.0545, 정탐율: 1.0000
# 709번째 시도 한계점: 0.709, 오탐율:0.0545, 정탐율: 1.0000
# 708번째 시도 한계점: 0.708, 오탐율:0.0545, 정탐율: 1.0000
# 707번째 시도 한계점: 0.707, 오탐율:0.0545, 정탐율: 1.0000
# 706번째 시도 한계점: 0.706, 오탐율:0.0545, 정탐율: 1.0000
# 705번째 시도 한계점: 0.705, 오탐율:0.0545, 정탐율: 1.0000
# 704번째 시도 한계점: 0.704, 오탐율:0.0545, 정탐율: 1.0000
# 703번째 시도 한계점: 0.703, 오탐율:0.0545, 정탐율: 1.0000
# 702번째 시도 한계점: 0.702, 오탐율:0.0545, 정탐율: 1.0000
# 701번째 시도 한계점: 0.701, 오탐율:0.0545, 정탐율: 1.0000
# 700번째 시도 한계점: 0.700, 오탐율:0.0545, 정탐율: 1.0000
# 699번째 시도 한계점: 0.699, 오탐율:0.0545, 정탐율: 1.0000
# 698번째 시도 한계점: 0.698, 오탐율:0.0545, 정탐율: 1.0000
# 697번째 시도 한계점: 0.697, 오탐율:0.0545, 정탐율: 1.0000
# 696번째 시도 한계점: 0.696, 오탐율:0.0545, 정탐율: 1.0000
# 695번째 시도 한계점: 0.695, 오탐율:0.0545, 정탐율: 1.0000
# 694번째 시도 한계점: 0.694, 오탐율:0.0545, 정탐율: 1.0000
# 693번째 시도 한계점: 0.693, 오탐율:0.0545, 정탐율: 1.0000
# 692번째 시도 한계점: 0.692, 오탐율:0.0545, 정탐율: 1.0000
# 691번째 시도 한계점: 0.691, 오탐율:0.0545, 정탐율: 1.0000
# 690번째 시도 한계점: 0.690, 오탐율:0.0545, 정탐율: 1.0000
# 689번째 시도 한계점: 0.689, 오탐율:0.0545, 정탐율: 1.0000
# 688번째 시도 한계점: 0.688, 오탐율:0.0545, 정탐율: 1.0000
# 687번째 시도 한계점: 0.687, 오탐율:0.0545, 정탐율: 1.0000
# 686번째 시도 한계점: 0.686, 오탐율:0.0545, 정탐율: 1.0000
# 685번째 시도 한계점: 0.685, 오탐율:0.0545, 정탐율: 1.0000
# 684번째 시도 한계점: 0.684, 오탐율:0.0545, 정탐율: 1.0000
# 683번째 시도 한계점: 0.683, 오탐율:0.0545, 정탐율: 1.0000
# 682번째 시도 한계점: 0.682, 오탐율:0.0545, 정탐율: 1.0000
# 681번째 시도 한계점: 0.681, 오탐율:0.0545, 정탐율: 1.0000
# 680번째 시도 한계점: 0.680, 오탐율:0.0545, 정탐율: 1.0000
# 679번째 시도 한계점: 0.679, 오탐율:0.0545, 정탐율: 1.0000
# 678번째 시도 한계점: 0.678, 오탐율:0.0545, 정탐율: 1.0000
# 677번째 시도 한계점: 0.677, 오탐율:0.0545, 정탐율: 1.0000
# 676번째 시도 한계점: 0.676, 오탐율:0.0545, 정탐율: 1.0000
# 675번째 시도 한계점: 0.675, 오탐율:0.0545, 정탐율: 1.0000
# 674번째 시도 한계점: 0.674, 오탐율:0.0545, 정탐율: 1.0000
# 673번째 시도 한계점: 0.673, 오탐율:0.0545, 정탐율: 1.0000
# 672번째 시도 한계점: 0.672, 오탐율:0.0545, 정탐율: 1.0000
# 671번째 시도 한계점: 0.671, 오탐율:0.0545, 정탐율: 1.0000
# 670번째 시도 한계점: 0.670, 오탐율:0.0545, 정탐율: 1.0000
# 669번째 시도 한계점: 0.669, 오탐율:0.0545, 정탐율: 1.0000
# 668번째 시도 한계점: 0.668, 오탐율:0.0545, 정탐율: 1.0000
# 667번째 시도 한계점: 0.667, 오탐율:0.0545, 정탐율: 1.0000
# 666번째 시도 한계점: 0.666, 오탐율:0.0545, 정탐율: 1.0000
# 665번째 시도 한계점: 0.665, 오탐율:0.0545, 정탐율: 1.0000
# 664번째 시도 한계점: 0.664, 오탐율:0.0545, 정탐율: 1.0000
# 663번째 시도 한계점: 0.663, 오탐율:0.0545, 정탐율: 1.0000
# 662번째 시도 한계점: 0.662, 오탐율:0.0545, 정탐율: 1.0000
# 661번째 시도 한계점: 0.661, 오탐율:0.0545, 정탐율: 1.0000
# 660번째 시도 한계점: 0.660, 오탐율:0.0545, 정탐율: 1.0000
# 659번째 시도 한계점: 0.659, 오탐율:0.0545, 정탐율: 1.0000
# 658번째 시도 한계점: 0.658, 오탐율:0.0545, 정탐율: 1.0000
# 657번째 시도 한계점: 0.657, 오탐율:0.0545, 정탐율: 1.0000
# 656번째 시도 한계점: 0.656, 오탐율:0.0545, 정탐율: 1.0000
# 655번째 시도 한계점: 0.655, 오탐율:0.0545, 정탐율: 1.0000
# 654번째 시도 한계점: 0.654, 오탐율:0.0545, 정탐율: 1.0000
# 653번째 시도 한계점: 0.653, 오탐율:0.0545, 정탐율: 1.0000
# 652번째 시도 한계점: 0.652, 오탐율:0.0545, 정탐율: 1.0000
# 651번째 시도 한계점: 0.651, 오탐율:0.0545, 정탐율: 1.0000
# 650번째 시도 한계점: 0.650, 오탐율:0.0545, 정탐율: 1.0000
# 649번째 시도 한계점: 0.649, 오탐율:0.0545, 정탐율: 1.0000
# 648번째 시도 한계점: 0.648, 오탐율:0.0545, 정탐율: 1.0000
# 647번째 시도 한계점: 0.647, 오탐율:0.0545, 정탐율: 1.0000
# 646번째 시도 한계점: 0.646, 오탐율:0.0045, 정탐율: 0.7857
#
# Selected threshold:
# 0.646
